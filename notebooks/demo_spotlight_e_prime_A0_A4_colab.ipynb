# %% [markdown]
# <a href="https://colab.research.google.com/github/tburleyinfo/vLLM-Hook/blob/codex/MLR-20-eprime-wandb-integration/notebooks/demo_spotlight_e_prime_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spotlight E-Prime Constraint Retention In Colab [A0_A4]
#
# Frozen provenance copy of `demo_spotlight_e_prime_colab.ipynb` for the canonical MLR-20 A0-A4 alpha sweep. It preserves the executed A0-A4 outputs already present in the source notebook; do not edit this copy for C-series implementation work.
#
# This notebook runs a long-conversation E-Prime constraint-retention experiment with baseline generation and Spotlight-steered generation. It uses the CUDA/vLLM Colab `HookLLM` path and intentionally avoids Apple Silicon/Metal support.

# %% [markdown]
# ### Installation
#
# Run this setup cell once in a fresh Colab GPU runtime before continuing. It clones the repo and installs the CUDA-compatible notebook dependencies.

# %%
# ==============================================================================
# VLLM HOOK SETUP AND DEPENDENCY MANAGER
# ==============================================================================
#
# PURPOSE:
# This cell prepares the environment to run vLLM and its custom plugins.
# It handles complex dependency conflicts common in Colab (e.g., pre-installed
# torch versions) and ensures the plugin code is loaded correctly.
#
# KEY ACTIONS:
# 1. Clones the vLLM-Hook repository if not present.
# 2. Installs a compatible version of vLLM and PyTorch for your GPU.
# 3. Cleans up old binary artifacts to prevent version conflicts.
# 4. Loads the plugin source code.
# 5. TRIGGERS A COLAB RESTART: The cell will restart the runtime to ensure
#    the new libraries are fully loaded into the kernel memory.
#
# EXPECTED BEHAVIOR:
# - The cell will run and install packages.
# - It may print "Restarting Colab runtime...".
# - The cell will stop abruptly, and the runtime will restart.
# - The restart is automatic; the code will resume from the top.
# ==============================================================================

from pathlib import Path
import importlib
import importlib.util
import os
import re
import shutil
import site
import subprocess
import sys
import time

# Configuration
REPO_URL = os.environ.get("VLLM_HOOK_REPO_URL", "https://github.com/tburleyinfo/vLLM-Hook.git")
REPO_BRANCH = os.environ.get("VLLM_HOOK_REPO_BRANCH", "codex/MLR-20-eprime-wandb-integration")
REPO_NAME = "vLLM-Hook"

# Environment Variables (Optional overrides)
COLAB_INSTALL_VLLM = os.environ.get("COLAB_INSTALL_VLLM", "")
VLLM_SPEC = os.environ.get("VLLM_SPEC", "vllm>=0.11,<0.19")
VLLM_TORCH_BACKEND = os.environ.get("VLLM_TORCH_BACKEND", "cu128")

IN_COLAB = "google.colab" in sys.modules
NOTEBOOK_DIR = Path.cwd()

# --------------------------------------------------------------------------
# Helper Functions
# --------------------------------------------------------------------------

def run(cmd, cwd=None, env=None):
    """
    Executes a shell command, printing output in real-time.
    Raises an error if the command fails.
    """
    cmd = [str(part) for part in cmd]
    print(f"> Running: {' '.join(cmd)}", flush=True)

    process = subprocess.Popen(
        cmd,
        cwd=str(cwd) if cwd else None,
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )

    tail = []
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="", flush=True)
        tail = tail[-120:]

    returncode = process.wait()
    if returncode:
        tail_text = "\n".join(tail)
        raise RuntimeError(
            f"Command failed with exit code {returncode}: {' '.join(cmd)}\n\n"
            f"Last output lines:\n{tail_text}"
        )

def run_capture(cmd):
    """Executes a command and returns stdout/stderr without printing."""
    return subprocess.run([str(part) for part in cmd], text=True, capture_output=True, check=False)

def norm(name):
    """Normalize package names for comparison."""
    return name.lower().replace("_", "-")

def package_from_req_line(line: str) -> str:
    """Extract package name from a requirement string (e.g., 'torch>=1.0' -> 'torch')."""
    stripped = line.strip()
    # Split on version specifiers
    package = re.split(r"==|>=|<=|~=|!=|<|>|\[", stripped, maxsplit=1)[0]
    return norm(package.strip())

def _repo_remote_matches(repo_root: Path, expected_remote: str) -> bool:
    """Checks if the git repo's origin matches the expected URL."""
    try:
        url = subprocess.run(
            ["git", "-C", str(repo_root), "remote", "get-url", "origin"],
            check=True,
            capture_output=True,
            text=True,
        ).stdout.strip().removesuffix(".git")
    except Exception:
        return False
    return url == expected_remote

def _find_existing_repo_root(start_dir: Path, expected_remote: str):
    """Searches up the directory tree for a matching git repo."""
    for candidate in [start_dir, *start_dir.parents]:
        if (candidate / ".git").exists() and _repo_remote_matches(candidate, expected_remote):
            return candidate
    return None

def assert_cuda_runtime():
    """Ensures a GPU is available before proceeding."""
    try:
        import torch
    except Exception:
        torch = None

    has_cuda = bool(torch is not None and torch.cuda.is_available())
    has_cudart = importlib.util.find_spec("nvidia.cuda_runtime") is not None

    if not has_cuda and not has_cudart:
        raise RuntimeError(
            "No CUDA GPU detected. "
            "In Colab, go to Runtime > Change runtime type and select T4 GPU (or better), "
            "then re-run the entire notebook from the beginning."
        )

# --------------------------------------------------------------------------
# 1. Repository Setup
# --------------------------------------------------------------------------

expected_remote = REPO_URL.removesuffix(".git")
existing_repo_root = _find_existing_repo_root(NOTEBOOK_DIR, expected_remote)

if IN_COLAB:
    if existing_repo_root is not None:
        REPO_ROOT = existing_repo_root
        print(f"Refreshing existing repo at: {REPO_ROOT}")
        run(["git", "-C", str(REPO_ROOT), "fetch", "origin", REPO_BRANCH])
        run(["git", "-C", str(REPO_ROOT), "checkout", REPO_BRANCH])
        run(["git", "-C", str(REPO_ROOT), "pull", "--ff-only", "origin", REPO_BRANCH])
    else:
        REPO_ROOT = Path("/content") / REPO_NAME
        if not REPO_ROOT.exists():
            print(f"Cloning {REPO_URL} (branch: {REPO_BRANCH})...")
            run(["git", "clone", "--branch", REPO_BRANCH, REPO_URL, str(REPO_ROOT)])
        elif not _repo_remote_matches(REPO_ROOT, expected_remote):
            print(f"Remote mismatch detected. Replacing clone...")
            shutil.rmtree(REPO_ROOT)
            run(["git", "clone", "--branch", REPO_BRANCH, REPO_URL, str(REPO_ROOT)])
        else:
            print(f"Refreshing existing clone...")
            run(["git", "-C", str(REPO_ROOT), "fetch", "origin", REPO_BRANCH])
            run(["git", "-C", str(REPO_ROOT), "checkout", REPO_BRANCH])
            run(["git", "-C", str(REPO_ROOT), "pull", "--ff-only", "origin", REPO_BRANCH])

    NOTEBOOK_DIR = REPO_ROOT / "notebooks"
    os.chdir(NOTEBOOK_DIR)
    print(f"Working directory set to: {NOTEBOOK_DIR}")
else:
    REPO_ROOT = NOTEBOOK_DIR.parent

PKG_DIR = REPO_ROOT / "vllm_hook_plugins"
REQ_FILE = REPO_ROOT / "requirement.txt"
FILTERED_REQ_FILE = Path("/tmp/vllm_hook_colab_requirements.txt")
COLAB_RESTART_MARKER = Path("/tmp/vllm_hook_colab_binary_deps_restarted")

print(f"\n--- Environment Summary ---")
print(f"Running in Colab: {IN_COLAB}")
print(f"Repo Root: {REPO_ROOT}")
print(f"Plugin Dir: {PKG_DIR}")

if IN_COLAB:
    assert_cuda_runtime()

# --------------------------------------------------------------------------
# 2. Plugin Directory Validation
# --------------------------------------------------------------------------

if not PKG_DIR.exists():
    raise FileNotFoundError(
        f"Plugin directory not found at {PKG_DIR}. "
        "Please ensure the repository was cloned correctly."
    )

if shutil.which("git") is None and IN_COLAB:
    raise RuntimeError("git is required but unavailable in this runtime.")

# --------------------------------------------------------------------------
# 3. Dependency Management
# --------------------------------------------------------------------------

if REQ_FILE.exists():
    keep = []
    # These packages are managed by Colab's pre-installed environment.
    # Installing them again can cause conflicts.
    blocked = {"vllm", "torch", "torchvision", "torchaudio", "numpy", "scipy", "protobuf"}

    for line in REQ_FILE.read_text().splitlines():
        stripped = line.strip()
        if not stripped or stripped.startswith("#"):
            keep.append(line)
            continue

        package = package_from_req_line(stripped)
        if package in blocked:
            print(f"⏭ Skipping managed dependency: {line}")
            continue
        keep.append(line)

    FILTERED_REQ_FILE.write_text("\n".join(keep) + "\n")
    print(f"Installing filtered requirements from {REQ_FILE.name}...")
    run([sys.executable, "-m", "pip", "install", "-r", str(FILTERED_REQ_FILE)])
else:
    print("⚠ Warning: No requirement.txt found; skipping custom dependency installation.")

# Ensure protobuf is at the correct version
print("Ensuring protobuf version compatibility...")
run([sys.executable, "-m", "pip", "install", "--force-reinstall", "protobuf>=5.29.6,<6.30"])

# --------------------------------------------------------------------------
# 4. vLLM & PyTorch Installation
# --------------------------------------------------------------------------

if COLAB_INSTALL_VLLM:
    print(f"Installing user-specified vLLM: {COLAB_INSTALL_VLLM}")
    run([sys.executable, "-m", "pip", "install", COLAB_INSTALL_VLLM])
else:
    print(f"\nInstalling vLLM and PyTorch for {VLLM_TORCH_BACKEND}...")

    # 1. Uninstall existing conflicting versions
    run([sys.executable, "-m", "pip", "uninstall", "-y", "vllm", "torch", "torchvision", "torchaudio"])

    # 2. Manually remove leftover binary artifacts that pip might miss
    for site_dir in site.getsitepackages():
        site_path = Path(site_dir)
        leftovers = [
            site_path / "vllm", *site_path.glob("vllm-*.dist-info"),
            site_path / "torch", *site_path.glob("torch-*.dist-info"),
            site_path / "torchvision", *site_path.glob("torchvision-*.dist-info"),
            site_path / "torchaudio", *site_path.glob("torchaudio-*.dist-info"),
        ]
        for leftover in leftovers:
            if leftover.exists():
                print(f"  Cleaning up leftover: {leftover.name}")
                if leftover.is_dir():
                    shutil.rmtree(leftover)
                else:
                    leftover.unlink()

    # 3. Force clear GPU memory
    try:
        import torch
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            torch.cuda.synchronize()
    except:
        pass

    # 4. Install using 'uv' (faster than pip) with specific CUDA backend
    print("  Downloading and installing packages with 'uv'...")
    run([sys.executable, "-m", "pip", "install", "-U", "uv"])
    run([
        "uv", "pip", "install",
        "--system",
        VLLM_SPEC,
        "torch", "torchvision", "torchaudio",
        f"--torch-backend={VLLM_TORCH_BACKEND}",
    ])

    # 5. Verify Scipy/Numpy
    scipy_check = run_capture([
        sys.executable, "-c", "import numpy, scipy; print('numpy', numpy.__version__); print('scipy', scipy.__version__)"
    ])
    if scipy_check.returncode:
        print("  Detected numpy/scipy issues; upgrading...")
        run([sys.executable, "-m", "pip", "install", "--upgrade", "--force-reinstall", "numpy", "scipy"])

# Verify Installation
print("\nVerifying installation...")
run([
    sys.executable,
    "-c",
    "import torch, vllm; print('✓ torch:', torch.__version__); print('✓ vllm:', getattr(vllm, '__version__', 'unknown'))"
])

# --------------------------------------------------------------------------
# 5. Plugin Loading
# --------------------------------------------------------------------------

# Strategy: Add path to sys.path to allow immediate import,
# then ensure metadata is installed for subprocesses later.
plugin_src_dir = str(PKG_DIR.resolve())
if plugin_src_dir not in sys.path:
    sys.path.insert(0, plugin_src_dir)
importlib.invalidate_caches()

try:
    spec = importlib.util.spec_from_file_location("vllm_hook_plugins", PKG_DIR / "__init__.py")
    if spec:
        importlib.util.module_from_spec(spec)
        print("✓ Plugin module loaded successfully from source path.")
except Exception as e:
    print(f"⚠ Warning: Initial import check failed ({e}). This is expected if compilation is needed later.")

# Ensure the package is registered in the environment (metadata)
# This is necessary for tools that rely on `importlib.metadata`.
print("Registering plugin package in environment...")
run([sys.executable, "-m", "pip", "install", "--no-deps", "-e", str(PKG_DIR)])

print("Installing W&B tracking client...")
run([sys.executable, "-m", "pip", "install", "wandb"])

print(f"Plugin Source: {plugin_src_dir}")
print(f"Python Exec  : {sys.executable}")

# --------------------------------------------------------------------------
# 6. Runtime Restart (Critical for Colab)
# --------------------------------------------------------------------------
# We restart the runtime to ensure the newly installed binary libraries
# are loaded into a fresh Python interpreter. This prevents "dirty state" issues.
if IN_COLAB and not COLAB_RESTART_MARKER.exists():
    COLAB_RESTART_MARKER.write_text("1\n")
    print("\n" + "="*50)
    print("RESTARTING COLAB RUNTIME...")
    print("This ensures the new vLLM/Torch binaries are fully loaded.")
    print("Do not interrupt this process.")
    print("="*50)

    time.sleep(1) # Allow output buffer to flush
    sys.exit(0) # Terminate this process to trigger Colab restart
# Out:
# Refreshing existing clone...
# > Running: git -C /content/vLLM-Hook fetch origin codex/MLR-20-eprime-wandb-integration
# From https://github.com/tburleyinfo/vLLM-Hook
#  * branch            codex/MLR-20-eprime-wandb-integration -> FETCH_HEAD
#    cf79e77..a704b0d  codex/MLR-20-eprime-wandb-integration -> origin/codex/MLR-20-eprime-wandb-integration
# > Running: git -C /content/vLLM-Hook checkout codex/MLR-20-eprime-wandb-integration
# Already on 'codex/MLR-20-eprime-wandb-integration'
# Your branch is behind 'origin/codex/MLR-20-eprime-wandb-integration' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# > Running: git -C /content/vLLM-Hook pull --ff-only origin codex/MLR-20-eprime-wandb-integration
# From https://github.com/tburleyinfo/vLLM-Hook
#  * branch            codex/MLR-20-eprime-wandb-integration -> FETCH_HEAD
# Updating cf79e77..a704b0d
# Fast-forward
#  notebooks/demo_spotlight_e_prime_colab.ipynb | 262 +++++++++++++++++++++++++--
#  1 file changed, 245 insertions(+), 17 deletions(-)
# Working directory set to: /content/vLLM-Hook/notebooks
#
# --- Environment Summary ---
# Running in Colab: True
# Repo Root: /content/vLLM-Hook
# Plugin Dir: /content/vLLM-Hook/vllm_hook_plugins
# ⏭ Skipping managed dependency: vllm>=0.5
# ⏭ Skipping managed dependency: torch>=2.0
# ⏭ Skipping managed dependency: numpy>=1.24
# Installing filtered requirements from requirement.txt...
# > Running: /usr/bin/python3 -m pip install -r /tmp/vllm_hook_colab_requirements.txt
# Requirement already satisfied: blake3 in /usr/local/lib/python3.13/dist-packages (from -r /tmp/vllm_hook_colab_requirements.txt (line 1)) (1.0.9)
# Ensuring protobuf version compatibility...
# > Running: /usr/bin/python3 -m pip install --force-reinstall protobuf>=5.29.6,<6.30
# Collecting protobuf<6.30,>=5.29.6
#   Using cached protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Using cached protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl (320 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# Successfully installed protobuf-5.29.6
#
# Installing vLLM and PyTorch for cu128...
# > Running: /usr/bin/python3 -m pip uninstall -y vllm torch torchvision torchaudio
# Found existing installation: vllm 0.18.1
# Uninstalling vllm-0.18.1:
#   Successfully uninstalled vllm-0.18.1
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
#   Downloading and installing packages with 'uv'...
# > Running: /usr/bin/python3 -m pip install -U uv
# Requirement already satisfied: uv in /usr/local/lib/python3.13/dist-packages (0.12.17)
# > Running: uv pip install --system vllm>=0.11,<0.19 torch torchvision torchaudio --torch-backend=cu128
# Using Python 3.13.15 environment at: /usr
# Resolved 179 packages in 447ms
# Prepared 3 packages in 0.56ms
# Installed 4 packages in 198ms
#  + torch==2.10.0+cu128
#  + torchaudio==2.10.0+cu128
#  + torchvision==0.25.0+cu128
#  + vllm==0.18.1
#
# Verifying installation...
# > Running: /usr/bin/python3 -c import torch, vllm; print('✓ torch:', torch.__version__); print('✓ vllm:', getattr(vllm, '__version__', 'unknown'))
# ✓ torch: 2.10.0+cu128
# ✓ vllm: 0.18.1
# ✓ Plugin module loaded successfully from source path.
# Registering plugin package in environment...
# > Running: /usr/bin/python3 -m pip install --no-deps -e /content/vLLM-Hook/vllm_hook_plugins
# Obtaining file:///content/vLLM-Hook/vllm_hook_plugins
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: vllm-hook-plugins
#   Attempting uninstall: vllm-hook-plugins
#     Found existing installation: vllm-hook-plugins 0.2.0
#     Uninstalling vllm-hook-plugins-0.2.0:
#       Successfully uninstalled vllm-hook-plugins-0.2.0
#   Running setup.py develop for vllm-hook-plugins
# Successfully installed vllm-hook-plugins-0.2.0
# Installing W&B tracking client...
# > Running: /usr/bin/python3 -m pip install wandb
# Requirement already satisfied: wandb in /usr/local/lib/python3.13/dist-packages (0.28.1)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from wandb) (26.3)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from wandb) (4.11.7)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>=5 in /usr/local/lib/python3.13/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.13.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from wandb) (2.68.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.13/dist-packages (from wandb) (4.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.6->wandb) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.6->wandb) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.0.0->wandb) (2026.7.22)
# Plugin Source: /content/vLLM-Hook/vllm_hook_plugins
# Python Exec  : /usr/bin/python3

# %% [markdown]
# ### Scoring Dependencies
#
# The E-Prime checker uses spaCy for state-of-being verb detection. Run this cell before scoring.

# %%
# Optional scoring dependency setup for Colab.
# Run after the main setup cell. If you already have spaCy and en_core_web_sm, this is a no-op.
import importlib.util
import subprocess
import sys

if importlib.util.find_spec("spacy") is None:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "spacy"])

try:
    import spacy
    spacy.load("en_core_web_sm", disable=["ner", "parser"])
except OSError:
    subprocess.check_call([sys.executable, "-m", "spacy", "download", "en_core_web_sm"])

# %% [markdown]
# ### Imports & Environment

# %%
import gc
import io
import json
import os
import multiprocessing as mp
import re
import subprocess
import sys
import time
from datetime import datetime
from pathlib import Path

import pandas as pd
import torch
from vllm import SamplingParams

if str(REPO_ROOT) not in sys.path:
    sys.path.append(str(REPO_ROOT))

from vllm_hook_plugins import HookLLM, generate_with_spotlight, register_plugins
from research.experiment_tracking import (
    ExperimentCondition,
    ExperimentResult,
    RunMetrics,
    TurnResult,
    WandbTracker,
    evaluate_mlr20_condition,
    log_mlr20_results_sequentially,
    mlr20_alpha_sweep_conditions,
    run_mlr20_batch,
    collect_runtime_provenance,
    format_gib,
    has_required_vram,
    required_vram_bytes,
    turn_result_from_eprime_row,
)

IN_COLAB = "google.colab" in sys.modules
os.environ["VLLM_USE_V1"] = "1"

if IN_COLAB:
    mp.set_start_method("fork", force=True)
    os.environ["VLLM_WORKER_MULTIPROC_METHOD"] = "fork"
    os.environ["VLLM_ENABLE_V1_MULTIPROCESSING"] = "0"
    os.environ.setdefault("HF_HOME", "/content/.cache/huggingface")
    os.environ.setdefault("HUGGINGFACE_HUB_CACHE", "/content/.cache/huggingface/hub")
    os.makedirs(os.environ["HUGGINGFACE_HUB_CACHE"], exist_ok=True)

    def _patch_fileno(stream, fallback_stream, fallback_fd):
        try:
            stream.fileno()
        except io.UnsupportedOperation:
            def _fileno():
                try:
                    return fallback_stream.fileno()
                except Exception:
                    return fallback_fd
            stream.fileno = _fileno

    _patch_fileno(sys.stdout, sys.__stdout__, 1)
    _patch_fileno(sys.stderr, sys.__stderr__, 2)
else:
    mp.set_start_method("spawn", force=True)
    os.environ["VLLM_WORKER_MULTIPROC_METHOD"] = "spawn"

register_plugins()
print("Environment configured")
# Out:
# Environment configured

# %% [markdown]
# ### GPU Memory Preflight

# %%
def show_nvidia_smi():
    if not IN_COLAB:
        return
    try:
        completed = subprocess.run(
            ["nvidia-smi"],
            check=False,
            capture_output=True,
            text=True,
        )
    except FileNotFoundError:
        print("nvidia-smi unavailable in this runtime.")
        return
    if completed.stdout.strip():
        print(completed.stdout)
    if completed.stderr.strip():
        print(completed.stderr)


def cuda_memory_preflight(gpu_memory_utilization, *, show_smi=True):
    gc.collect()
    if not torch.cuda.is_available():
        raise RuntimeError(
            "CUDA is unavailable. In Colab, select a GPU runtime, restart the runtime, "
            "and run the notebook from the beginning."
        )

    torch.cuda.empty_cache()
    if hasattr(torch.cuda, "ipc_collect"):
        try:
            torch.cuda.ipc_collect()
        except Exception as exc:
            print(f"torch.cuda.ipc_collect() skipped: {exc}")

    free_bytes, total_bytes = torch.cuda.mem_get_info()
    required_bytes = required_vram_bytes(total_bytes, gpu_memory_utilization)
    print(
        "CUDA memory after cleanup: "
        f"free={format_gib(free_bytes)} total={format_gib(total_bytes)} "
        f"required={format_gib(required_bytes)} "
        f"for gpu_memory_utilization={gpu_memory_utilization:.2f}"
    )

    if show_smi:
        show_nvidia_smi()

    if not has_required_vram(
        free_bytes=free_bytes,
        total_bytes=total_bytes,
        gpu_memory_utilization=gpu_memory_utilization,
    ):
        raise RuntimeError(
            "Not enough free CUDA memory for the configured vLLM reservation. "
            f"Free={format_gib(free_bytes)}, required={format_gib(required_bytes)}, "
            f"total={format_gib(total_bytes)}, "
            f"gpu_memory_utilization={gpu_memory_utilization:.2f}. "
            "Restart the Colab runtime and choose Runtime > Run all. "
            "Do not continue from a partially executed runtime."
        )

    return {
        "free_bytes": free_bytes,
        "total_bytes": total_bytes,
        "required_bytes": required_bytes,
    }

# %% [markdown]
# ### Initialize `HookLLM`

# %%
cache_dir = "/content/.cache/vllm-hook" if IN_COLAB else os.path.expanduser("~/.cache/vllm-hook")
model = "Qwen/Qwen2-1.5B-Instruct"
MAX_MODEL_LEN = 8192
GPU_MEMORY_UTILIZATION = float(os.environ.get("VLLM_HOOK_GPU_MEMORY_UTILIZATION", "0.30" if IN_COLAB else "0.65"))

gpu_memory_preflight = cuda_memory_preflight(GPU_MEMORY_UTILIZATION)

llm = HookLLM(
    model=model,
    worker_name="probe_spotlight",
    download_dir=cache_dir,
    trust_remote_code=True,
    dtype=torch.float16,
    enable_hook=True,
    gpu_memory_utilization=GPU_MEMORY_UTILIZATION,
    max_model_len=MAX_MODEL_LEN,
    max_num_seqs=1,
    enforce_eager=True,
    enable_prefix_caching=False,
    enable_chunked_prefill=False,
    tensor_parallel_size=1,
)

print(f"Model loaded: {model}")
print("Spotlight worker enabled")
print(f"Max model length: {MAX_MODEL_LEN}")
print(f"GPU memory utilization: {GPU_MEMORY_UTILIZATION}")
# Out:
# CUDA memory after cleanup: free=78.83 GiB total=79.25 GiB required=23.78 GiB for gpu_memory_utilization=0.30
# Fri Sep 18 19:10:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   34C    P0             58W /  400W |     428MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           13670      C   /usr/bin/python3                        416MiB |
# +-----------------------------------------------------------------------------------------+
#
# INFO 09-18 19:10:47 [utils.py:233] non-default args: {'trust_remote_code': True, 'download_dir': '/content/.cache/vllm-hook', 'dtype': torch.float16, 'max_model_len': 8192, 'enable_prefix_caching': False, 'gpu_memory_utilization': 0.3, 'max_num_seqs': 1, 'disable_log_stats': True, 'enforce_eager': True, 'enable_chunked_prefill': False, 'worker_extension_cls': 'vllm_hook_plugins.workers.spotlight_worker.SpotlightWorker', 'model': 'Qwen/Qwen2-1.5B-Instruct'}
# WARNING 09-18 19:10:47 [envs.py:1717] Unknown vLLM environment variable detected: VLLM_USE_V1
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# WARNING 09-18 19:10:57 [arg_utils.py:1352] The global random seed is set to 0. Since VLLM_ENABLE_V1_MULTIPROCESSING is set to False, this may affect the random state of the Python process that launched vLLM.
# INFO 09-18 19:10:58 [model.py:533] Resolved architecture: Qwen2ForCausalLM
# WARNING 09-18 19:10:58 [model.py:1920] Casting torch.bfloat16 to torch.float16.
# INFO 09-18 19:10:58 [model.py:1582] Using max model len 8192
# WARNING 09-18 19:10:58 [arg_utils.py:2080] This model does not officially support disabling chunked prefill. Disabling this manually may cause the engine to crash or produce incorrect outputs.
# INFO 09-18 19:10:58 [vllm.py:775] Asynchronous scheduling is enabled.
# WARNING 09-18 19:10:58 [vllm.py:809] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 09-18 19:10:58 [vllm.py:820] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 09-18 19:10:58 [vllm.py:985] Cudagraph is disabled under eager mode
# INFO 09-18 19:10:58 [compilation.py:289] Enabled custom fusions: norm_quant, act_quant
# INFO 09-18 19:11:00 [core.py:103] Initializing a V1 LLM engine (v0.18.1) with config: model='Qwen/Qwen2-1.5B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2-1.5B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=8192, download_dir='/content/.cache/vllm-hook', load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Qwen/Qwen2-1.5B-Instruct, enable_prefix_caching=False, enable_chunked_prefill=False, pooler_config=None, compilation_config={'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# INFO 09-18 19:11:01 [worker_base.py:269] Injected <class 'vllm_hook_plugins.workers.spotlight_worker.SpotlightWorker'> into <class 'vllm.v1.worker.gpu_worker.Worker'> for extended collective_rpc calls ['install_hooks']
# INFO 09-18 19:11:01 [parallel_state.py:1395] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:54577 backend=nccl
# INFO 09-18 19:11:01 [parallel_state.py:1717] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# INFO 09-18 19:11:02 [gpu_model_runner.py:4481] Starting to load model Qwen/Qwen2-1.5B-Instruct...
# INFO 09-18 19:11:04 [cuda.py:317] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# INFO 09-18 19:11:04 [flash_attn.py:598] Using FlashAttention version 2
# INFO 09-18 19:11:05 [weight_utils.py:618] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 09-18 19:11:06 [default_loader.py:384] Loading weights took 1.24 seconds
# INFO 09-18 19:11:07 [gpu_model_runner.py:4566] Model loading took 2.89 GiB memory and 2.914341 seconds
# INFO 09-18 19:11:10 [gpu_worker.py:456] Available KV cache memory: 20.26 GiB
# INFO 09-18 19:11:10 [kv_cache_utils.py:1316] GPU KV cache size: 758,848 tokens
# INFO 09-18 19:11:10 [kv_cache_utils.py:1321] Maximum concurrency for 8,192 tokens per request: 92.63x
# INFO 09-18 19:11:10 [core.py:281] init engine (profile, create kv cache, warmup model) took 2.46 seconds
# INFO 09-18 19:11:12 [llm.py:391] Supported tasks: ('generate',)
# Model loaded: Qwen/Qwen2-1.5B-Instruct
# Spotlight worker enabled
# Max model length: 8192
# GPU memory utilization: 0.3

# %% [markdown]
# ### E-Prime Long-Conversation Configuration

# %%
E_PRIME_CONSTRAINT = """Persistent E-Prime constraint:
Do not use state-of-being verbs: am, is, are, was, were, be, being, been.
Do not use contractions containing state-of-being verbs, including I'm, you're, we're, they're, he's, she's, it's, that's, and there's.
""".strip()

SYSTEM_MESSAGE = (
    "You are a concise assistant continuing a long Talk2AI-style conversation. "
    "Preserve the E-Prime constraint throughout the whole conversation while still answering helpfully."
)

SEED_HISTORY = [
    {"role": "user", "content": "I keep hearing that climate change discussions are exaggerated compared with other problems."},
    {"role": "assistant", "content": "Let's compare long-run measurements with the way headlines describe them."},
    {"role": "user", "content": "The headlines make me distrust the whole topic."},
    {"role": "assistant", "content": "Repeated alarm can make even strong evidence feel performative."},
]

USER_TURNS = [
    "What evidence should I look at if I want to avoid headline-driven conclusions?",
    "How do local weather experiences confuse the broader trend?",
    "What tradeoffs matter for households when policies raise energy costs?",
    "Where does adaptation make sense, and where does it fall short?",
    "How should poorer countries think about growth and emissions limits?",
    "What practical local policy question should I ask a city council candidate?",
    "How can I separate serious policy criticism from misinformation?",
    "What should climate communicators stop doing if they want skeptical people to listen?",
    "What should good-faith skeptics concede before debating policy?",
    "End with a cautious, practical position that still respects the evidence.",
]

ALPHA = 0.2
SAMPLING_PARAMS = SamplingParams(temperature=0.0, max_tokens=160)
MAX_USER_TURNS = min(10, len(USER_TURNS))
HISTORY_WINDOW_MESSAGES = 16

# %% [markdown]
# ### Prompt And Run Helpers

# %%
def render_e_prime_prompt(history, user_message):
    recent_history = history[-HISTORY_WINDOW_MESSAGES:]
    omitted_messages = max(0, len(history) - len(recent_history))
    transcript = "\n".join(
        f"{item['role'].upper()}: {item['content']}" for item in recent_history
    )
    if transcript:
        transcript += "\n"

    earlier_context = ""
    if omitted_messages:
        earlier_context = (
            f"Earlier conversation context: {omitted_messages} older messages are omitted "
            "from this prompt to keep the Colab run within memory limits. Continue the same conversation.\n\n"
        )

    return f"""{SYSTEM_MESSAGE}

{E_PRIME_CONSTRAINT}

{earlier_context}Recent conversation:
{transcript}USER: {user_message}
ASSISTANT:""".strip()



STATE_OF_BEING_CORE_WORDS = {"am", "is", "are", "was", "were", "be", "being", "been"}
STATE_OF_BEING_SPACY_MODEL = "en_core_web_sm"
CONTRACTION_PATTERN = re.compile(
    r"\b(?:i'm|you're|we're|they're|he's|she's|it's|that's|there's|what's|who's|where's|when's|why's|how's)\b",
    re.IGNORECASE,
)


def load_state_of_being_nlp(model_name=STATE_OF_BEING_SPACY_MODEL):
    try:
        import spacy
    except ModuleNotFoundError as exc:
        raise ModuleNotFoundError(
            "spaCy is required for the E-Prime checker. Run the scoring dependency setup cell first."
        ) from exc

    try:
        return spacy.load(model_name, disable=["ner", "parser"])
    except OSError as exc:
        raise OSError(
            f"spaCy model {model_name!r} is not installed. Run the scoring dependency setup cell first."
        ) from exc


state_of_being_nlp = load_state_of_being_nlp()


def is_state_of_being_token(token):
    lemma = token.lemma_.lower()
    text = token.text.lower()
    if lemma == "be" and token.pos_ in {"AUX", "VERB"}:
        return True
    return text in STATE_OF_BEING_CORE_WORDS and token.pos_ in {"AUX", "VERB"}


def check_e_prime_violations(text, nlp=state_of_being_nlp):
    text = text or ""
    doc = nlp(text)
    verb_matches = []
    for token in doc:
        if is_state_of_being_token(token):
            verb_matches.append(
                {
                    "text": token.text,
                    "lemma": token.lemma_,
                    "pos": token.pos_,
                    "tag": token.tag_,
                    "start": token.idx,
                    "end": token.idx + len(token.text),
                }
            )
    contraction_matches = [
        {"text": match.group(0), "start": match.start(), "end": match.end()}
        for match in CONTRACTION_PATTERN.finditer(text)
    ]
    violation_count = len(verb_matches) + len(contraction_matches)
    return {
        "state_of_being_count": len(verb_matches),
        "contraction_count": len(contraction_matches),
        "e_prime_violation_count": violation_count,
        "e_prime_retained": violation_count == 0,
        "e_prime_score": 1.0 if violation_count == 0 else 0.0,
        "state_of_being_matches": verb_matches,
        "contraction_matches": contraction_matches,
    }


def rows_from_experiment_results(experiment_results):
    rows = []
    for experiment_result in experiment_results:
        rows.extend(experiment_result.full_result["rows"])
    return rows

# %% [markdown]
# ### Run One Condition Or A0-A4 Batch

# %%
MLR20_CONDITIONS = mlr20_alpha_sweep_conditions(
    temperature=SAMPLING_PARAMS.temperature,
    max_tokens=SAMPLING_PARAMS.max_tokens,
    history_window_messages=HISTORY_WINDOW_MESSAGES,
    notebook="notebooks/demo_spotlight_e_prime_colab.ipynb",
)
conditions_by_id = {condition.condition_id: condition for condition in MLR20_CONDITIONS}
print("Loaded canonical MLR-20 conditions from the Notion Experimental Conditions matrix:")
for condition in MLR20_CONDITIONS:
    alpha = "N/A" if condition.alpha is None else condition.alpha
    print(f"  {condition.condition_id}: Spotlight={condition.spotlight} alpha={alpha}")

RUN_SINGLE_CONDITION_DEBUG = os.environ.get("MLR20_RUN_SINGLE_CONDITION_DEBUG", "0") == "1"
SELECTED_CONDITION_ID = os.environ.get("MLR20_SELECTED_CONDITION_ID", "A2")
selected_condition_result = None
if RUN_SINGLE_CONDITION_DEBUG:
    selected_condition_result = evaluate_mlr20_condition(
        condition=conditions_by_id[SELECTED_CONDITION_ID],
        llm=llm,
        sampling_params=SAMPLING_PARAMS,
        seed_history=SEED_HISTORY,
        user_turns=USER_TURNS,
        render_prompt=render_e_prime_prompt,
        score_fn=check_e_prime_violations,
        generate_with_spotlight_fn=generate_with_spotlight,
        spotlight_span=E_PRIME_CONSTRAINT,
        provenance=collect_runtime_provenance(REPO_ROOT),
    )
    print(f"Single-condition debug run complete: {SELECTED_CONDITION_ID}")

batch_started = time.perf_counter()
batch_provenance = collect_runtime_provenance(REPO_ROOT)
mlr20_batch_results = run_mlr20_batch(
    MLR20_CONDITIONS,
    llm=llm,
    sampling_params=SAMPLING_PARAMS,
    seed_history=SEED_HISTORY,
    user_turns=USER_TURNS,
    render_prompt=render_e_prime_prompt,
    score_fn=check_e_prime_violations,
    generate_with_spotlight_fn=generate_with_spotlight,
    spotlight_span=E_PRIME_CONSTRAINT,
    provenance=batch_provenance,
)
batch_elapsed_s = time.perf_counter() - batch_started
results = pd.DataFrame(rows_from_experiment_results(mlr20_batch_results))
print(f"A0-A4 batch complete in {batch_elapsed_s:.2f}s across {len(mlr20_batch_results)} conditions")
results
# Out:
# Loaded canonical MLR-20 conditions from the Notion Experimental Conditions matrix:
#   A0: Spotlight=False alpha=N/A
#   A1: Spotlight=True alpha=0.05
#   A2: Spotlight=True alpha=0.1
#   A3: Spotlight=True alpha=0.15
#   A4: Spotlight=True alpha=0.2
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Rendering prompts:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# A0-A4 batch complete in 93.94s across 5 conditions
#    condition  turn                                             prompt  \
# 0         A0     1  You are a concise assistant continuing a long ...
# 1         A0     2  You are a concise assistant continuing a long ...
# 2         A0     3  You are a concise assistant continuing a long ...
# 3         A0     4  You are a concise assistant continuing a long ...
# 4         A0     5  You are a concise assistant continuing a long ...
# 5         A0     6  You are a concise assistant continuing a long ...
# 6         A0     7  You are a concise assistant continuing a long ...
# 7         A0     8  You are a concise assistant continuing a long ...
# 8         A0     9  You are a concise assistant continuing a long ...
# 9         A0    10  You are a concise assistant continuing a long ...
# 10        A1     1  You are a concise assistant continuing a long ...
# 11        A1     2  You are a concise assistant continuing a long ...
# 12        A1     3  You are a concise assistant continuing a long ...
# 13        A1     4  You are a concise assistant continuing a long ...
# 14        A1     5  You are a concise assistant continuing a long ...
# 15        A1     6  You are a concise assistant continuing a long ...
# 16        A1     7  You are a concise assistant continuing a long ...
# 17        A1     8  You are a concise assistant continuing a long ...
# 18        A1     9  You are a concise assistant continuing a long ...
# 19        A1    10  You are a concise assistant continuing a long ...
# 20        A2     1  You are a concise assistant continuing a long ...
# 21        A2     2  You are a concise assistant continuing a long ...
# 22        A2     3  You are a concise assistant continuing a long ...
# 23        A2     4  You are a concise assistant continuing a long ...
# 24        A2     5  You are a concise assistant continuing a long ...
# 25        A2     6  You are a concise assistant continuing a long ...
# 26        A2     7  You are a concise assistant continuing a long ...
# 27        A2     8  You are a concise assistant continuing a long ...
# 28        A2     9  You are a concise assistant continuing a long ...
# 29        A2    10  You are a concise assistant continuing a long ...
# 30        A3     1  You are a concise assistant continuing a long ...
# 31        A3     2  You are a concise assistant continuing a long ...
# 32        A3     3  You are a concise assistant continuing a long ...
# 33        A3     4  You are a concise assistant continuing a long ...
# 34        A3     5  You are a concise assistant continuing a long ...
# 35        A3     6  You are a concise assistant continuing a long ...
# 36        A3     7  You are a concise assistant continuing a long ...
# 37        A3     8  You are a concise assistant continuing a long ...
# 38        A3     9  You are a concise assistant continuing a long ...
# 39        A3    10  You are a concise assistant continuing a long ...
# 40        A4     1  You are a concise assistant continuing a long ...
# 41        A4     2  You are a concise assistant continuing a long ...
# 42        A4     3  You are a concise assistant continuing a long ...
# 43        A4     4  You are a concise assistant continuing a long ...
# 44        A4     5  You are a concise assistant continuing a long ...
# 45        A4     6  You are a concise assistant continuing a long ...
# 46        A4     7  You are a concise assistant continuing a long ...
# 47        A4     8  You are a concise assistant continuing a long ...
# 48        A4     9  You are a concise assistant continuing a long ...
# 49        A4    10  You are a concise assistant continuing a long ...
#
#                                          user_message  \
# 0   What evidence should I look at if I want to av...
# 1   How do local weather experiences confuse the b...
# 2   What tradeoffs matter for households when poli...
# 3   Where does adaptation make sense, and where do...
# 4   How should poorer countries think about growth...
# 5   What practical local policy question should I ...
# 6   How can I separate serious policy criticism fr...
# 7   What should climate communicators stop doing i...
# 8   What should good-faith skeptics concede before...
# 9   End with a cautious, practical position that s...
# 10  What evidence should I look at if I want to av...
# 11  How do local weather experiences confuse the b...
# 12  What tradeoffs matter for households when poli...
# 13  Where does adaptation make sense, and where do...
# 14  How should poorer countries think about growth...
# 15  What practical local policy question should I ...
# 16  How can I separate serious policy criticism fr...
# 17  What should climate communicators stop doing i...
# 18  What should good-faith skeptics concede before...
# 19  End with a cautious, practical position that s...
# 20  What evidence should I look at if I want to av...
# 21  How do local weather experiences confuse the b...
# 22  What tradeoffs matter for households when poli...
# 23  Where does adaptation make sense, and where do...
# 24  How should poorer countries think about growth...
# 25  What practical local policy question should I ...
# 26  How can I separate serious policy criticism fr...
# 27  What should climate communicators stop doing i...
# 28  What should good-faith skeptics concede before...
# 29  End with a cautious, practical position that s...
# 30  What evidence should I look at if I want to av...
# 31  How do local weather experiences confuse the b...
# 32  What tradeoffs matter for households when poli...
# 33  Where does adaptation make sense, and where do...
# 34  How should poorer countries think about growth...
# 35  What practical local policy question should I ...
# 36  How can I separate serious policy criticism fr...
# 37  What should climate communicators stop doing i...
# 38  What should good-faith skeptics concede before...
# 39  End with a cautious, practical position that s...
# 40  What evidence should I look at if I want to av...
# 41  How do local weather experiences confuse the b...
# 42  What tradeoffs matter for households when poli...
# 43  Where does adaptation make sense, and where do...
# 44  How should poorer countries think about growth...
# 45  What practical local policy question should I ...
# 46  How can I separate serious policy criticism fr...
# 47  What should climate communicators stop doing i...
# 48  What should good-faith skeptics concede before...
# 49  End with a cautious, practical position that s...
#
#                                        model_response  compliant  \
# 0   Look at the long-term trends in temperature an...       True
# 1   Local weather can be influenced by local facto...      False
# 2   Energy costs can affect both the environment a...       True
# 3   Adaptation can help mitigate the effects of cl...      False
# 4   Poorer countries may need to prioritize adapta...       True
# 5   Ask about the city's plans for renewable energ...       True
# 6   Look for sources that are peer-reviewed and ha...      False
# 7   Avoid using scare tactics and focus on the sci...       True
# 8   Concede that climate change is real and that p...      False
# 9   Emphasize the importance of adaptation and mit...       True
# 10  Look for studies that have been peer-reviewed ...      False
# 11  Local weather experiences can be influenced by...      False
# 12  Energy costs can have significant impacts on h...      False
# 13  Adaptation can make sense in areas where the c...      False
# 14  Poorer countries may face unique challenges in...      False
# 15  What steps will the candidate take to reduce g...      False
# 16  It's important to distinguish between serious ...      False
# 17  It's important for climate communicators to be...      False
# 18  It's important for good-faith skeptics to ackn...      False
# 19  It's important for policymakers and communicat...      False
# 20  Look for studies that have been peer-reviewed ...      False
# 21  Local weather experiences can be influenced by...      False
# 22  Energy costs can have significant impacts on h...      False
# 23  Adaptation can make sense in areas where the c...      False
# 24  Poorer countries may face unique challenges in...      False
# 25  What steps will the candidate take to reduce g...      False
# 26  It's important to distinguish between serious ...      False
# 27  It's important for climate communicators to be...      False
# 28  It's important for good-faith skeptics to ackn...      False
# 29  It's important for policymakers and communicat...      False
# 30  Look for studies that have been peer-reviewed ...      False
# 31  Local weather experiences can be influenced by...      False
# 32  Energy costs can have significant impacts on h...      False
# 33  Adaptation can make sense in areas where the c...      False
# 34  Poorer countries may face unique challenges in...      False
# 35  What steps will the candidate take to reduce g...      False
# 36  It's important to distinguish between serious ...      False
# 37  It's important for climate communicators to be...      False
# 38  It's important for good-faith skeptics to ackn...      False
# 39  It's important for policymakers and communicat...      False
# 40  Look for studies that have been peer-reviewed ...      False
# 41  Local weather experiences can be influenced by...      False
# 42  Energy costs can have significant impacts on h...      False
# 43  Adaptation can make sense in areas where the c...      False
# 44  Poorer countries may face unique challenges in...      False
# 45  What steps will the candidate take to reduce g...      False
# 46  It's important to distinguish between serious ...      False
# 47  It's important for climate communicators to be...      False
# 48  It's important for good-faith skeptics to ackn...      False
# 49  It's important for policymakers and communicat...      False
#
#     violation_count  state_of_being_count  contraction_count  \
# 0                 0                     0                  0
# 1                 1                     1                  0
# 2                 0                     0                  0
# 3                 2                     1                  1
# 4                 0                     0                  0
# 5                 0                     0                  0
# 6                 1                     1                  0
# 7                 0                     0                  0
# 8                 2                     2                  0
# 9                 0                     0                  0
# 10                1                     1                  0
# 11                1                     1                  0
# 12                2                     1                  1
# 13                7                     6                  1
# 14                3                     2                  1
# 15                1                     1                  0
# 16               12                    10                  2
# 17                8                     7                  1
# 18                3                     2                  1
# 19                7                     4                  3
# 20                1                     1                  0
# 21                1                     1                  0
# 22                2                     1                  1
# 23                7                     6                  1
# 24                3                     2                  1
# 25                1                     1                  0
# 26               12                    10                  2
# 27                8                     7                  1
# 28                3                     2                  1
# 29                7                     4                  3
# 30                1                     1                  0
# 31                1                     1                  0
# 32                2                     1                  1
# 33                7                     6                  1
# 34                3                     2                  1
# 35                1                     1                  0
# 36               12                    10                  2
# 37                8                     7                  1
# 38                3                     2                  1
# 39                7                     4                  3
# 40                1                     1                  0
# 41                1                     1                  0
# 42                2                     1                  1
# 43                7                     6                  1
# 44                3                     2                  1
# 45                1                     1                  0
# 46               12                    10                  2
# 47                8                     7                  1
# 48                3                     2                  1
# 49                7                     4                  3
#
#      score_text_source  prompt_chars  history_messages_in_prompt  latency_s  \
# 0   assistant_response           845                           4   3.563385
# 1   assistant_response           986                           6   3.506129
# 2   assistant_response          1149                           8   3.502139
# 3   assistant_response          1298                          10   3.548336
# 4   assistant_response          1474                          12   3.420586
# 5   assistant_response          1660                          14   3.451146
# 6   assistant_response          1814                          16   3.480012
# 7   assistant_response          1963                          16   3.479572
# 8   assistant_response          1979                          16   3.440525
# 9   assistant_response          1990                          16   3.467108
# 10  assistant_response           845                           4   0.765552
# 11  assistant_response          1125                           6   1.037547
# 12  assistant_response          1484                           8   1.306778
# 13  assistant_response          1925                          10   1.731568
# 14  assistant_response          2441                          12   1.500492
# 15  assistant_response          2964                          14   0.748207
# 16  assistant_response          3222                          16   1.902640
# 17  assistant_response          3758                          16   2.021184
# 18  assistant_response          4212                          16   1.772400
# 19  assistant_response          4459                          16   1.952831
# 20  assistant_response           845                           4   0.748600
# 21  assistant_response          1125                           6   1.034000
# 22  assistant_response          1484                           8   1.276542
# 23  assistant_response          1925                          10   1.706807
# 24  assistant_response          2441                          12   1.494456
# 25  assistant_response          2964                          14   0.747883
# 26  assistant_response          3222                          16   1.932945
# 27  assistant_response          3758                          16   2.052401
# 28  assistant_response          4212                          16   1.770447
# 29  assistant_response          4459                          16   1.922667
# 30  assistant_response           845                           4   0.741134
# 31  assistant_response          1125                           6   1.014059
# 32  assistant_response          1484                           8   1.281659
# 33  assistant_response          1925                          10   1.706777
# 34  assistant_response          2441                          12   1.486624
# 35  assistant_response          2964                          14   0.743756
# 36  assistant_response          3222                          16   1.943422
# 37  assistant_response          3758                          16   2.017723
# 38  assistant_response          4212                          16   1.774827
# 39  assistant_response          4459                          16   1.940609
# 40  assistant_response           845                           4   0.759482
# 41  assistant_response          1125                           6   1.022337
# 42  assistant_response          1484                           8   1.265343
# 43  assistant_response          1925                          10   1.711214
# 44  assistant_response          2441                          12   1.470720
# 45  assistant_response          2964                          14   0.726216
# 46  assistant_response          3222                          16   1.899792
# 47  assistant_response          3758                          16   2.018390
# 48  assistant_response          4212                          16   1.760866
# 49  assistant_response          4459                          16   1.946886
#
#                                state_of_being_matches  \
# 0                                                  []
# 1   [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 2                                                  []
# 3   [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 4                                                  []
# 5                                                  []
# 6   [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 7                                                  []
# 8   [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 9                                                  []
# 10  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 11  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 12  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 13  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 14  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 15  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 16  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 17  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 18  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 19  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 20  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 21  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 22  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 23  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 24  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 25  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 26  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 27  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 28  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 29  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 30  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 31  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 32  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 33  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 34  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 35  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 36  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 37  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 38  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 39  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 40  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 41  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 42  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 43  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 44  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 45  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 46  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 47  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 48  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 49  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
#
#                                   contraction_matches  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3          [{'text': 'it's', 'start': 64, 'end': 68}]
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12       [{'text': 'It's', 'start': 253, 'end': 257}]
# 13       [{'text': 'It's', 'start': 276, 'end': 280}]
# 14       [{'text': 'It's', 'start': 281, 'end': 285}]
# 15                                                 []
# 16  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 17           [{'text': 'It's', 'start': 0, 'end': 4}]
# 18           [{'text': 'It's', 'start': 0, 'end': 4}]
# 19  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 20                                                 []
# 21                                                 []
# 22       [{'text': 'It's', 'start': 253, 'end': 257}]
# 23       [{'text': 'It's', 'start': 276, 'end': 280}]
# 24       [{'text': 'It's', 'start': 281, 'end': 285}]
# 25                                                 []
# 26  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 27           [{'text': 'It's', 'start': 0, 'end': 4}]
# 28           [{'text': 'It's', 'start': 0, 'end': 4}]
# 29  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 30                                                 []
# 31                                                 []
# 32       [{'text': 'It's', 'start': 253, 'end': 257}]
# 33       [{'text': 'It's', 'start': 276, 'end': 280}]
# 34       [{'text': 'It's', 'start': 281, 'end': 285}]
# 35                                                 []
# 36  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 37           [{'text': 'It's', 'start': 0, 'end': 4}]
# 38           [{'text': 'It's', 'start': 0, 'end': 4}]
# 39  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 40                                                 []
# 41                                                 []
# 42       [{'text': 'It's', 'start': 253, 'end': 257}]
# 43       [{'text': 'It's', 'start': 276, 'end': 280}]
# 44       [{'text': 'It's', 'start': 281, 'end': 285}]
# 45                                                 []
# 46  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 47           [{'text': 'It's', 'start': 0, 'end': 4}]
# 48           [{'text': 'It's', 'start': 0, 'end': 4}]
# 49  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
#
#                                                 reply  e_prime_score  \
# 0   Look at the long-term trends in temperature an...            1.0
# 1   Local weather can be influenced by local facto...            0.0
# 2   Energy costs can affect both the environment a...            1.0
# 3   Adaptation can help mitigate the effects of cl...            0.0
# 4   Poorer countries may need to prioritize adapta...            1.0
# 5   Ask about the city's plans for renewable energ...            1.0
# 6   Look for sources that are peer-reviewed and ha...            0.0
# 7   Avoid using scare tactics and focus on the sci...            1.0
# 8   Concede that climate change is real and that p...            0.0
# 9   Emphasize the importance of adaptation and mit...            1.0
# 10  Look for studies that have been peer-reviewed ...            0.0
# 11  Local weather experiences can be influenced by...            0.0
# 12  Energy costs can have significant impacts on h...            0.0
# 13  Adaptation can make sense in areas where the c...            0.0
# 14  Poorer countries may face unique challenges in...            0.0
# 15  What steps will the candidate take to reduce g...            0.0
# 16  It's important to distinguish between serious ...            0.0
# 17  It's important for climate communicators to be...            0.0
# 18  It's important for good-faith skeptics to ackn...            0.0
# 19  It's important for policymakers and communicat...            0.0
# 20  Look for studies that have been peer-reviewed ...            0.0
# 21  Local weather experiences can be influenced by...            0.0
# 22  Energy costs can have significant impacts on h...            0.0
# 23  Adaptation can make sense in areas where the c...            0.0
# 24  Poorer countries may face unique challenges in...            0.0
# 25  What steps will the candidate take to reduce g...            0.0
# 26  It's important to distinguish between serious ...            0.0
# 27  It's important for climate communicators to be...            0.0
# 28  It's important for good-faith skeptics to ackn...            0.0
# 29  It's important for policymakers and communicat...            0.0
# 30  Look for studies that have been peer-reviewed ...            0.0
# 31  Local weather experiences can be influenced by...            0.0
# 32  Energy costs can have significant impacts on h...            0.0
# 33  Adaptation can make sense in areas where the c...            0.0
# 34  Poorer countries may face unique challenges in...            0.0
# 35  What steps will the candidate take to reduce g...            0.0
# 36  It's important to distinguish between serious ...            0.0
# 37  It's important for climate communicators to be...            0.0
# 38  It's important for good-faith skeptics to ackn...            0.0
# 39  It's important for policymakers and communicat...            0.0
# 40  Look for studies that have been peer-reviewed ...            0.0
# 41  Local weather experiences can be influenced by...            0.0
# 42  Energy costs can have significant impacts on h...            0.0
# 43  Adaptation can make sense in areas where the c...            0.0
# 44  Poorer countries may face unique challenges in...            0.0
# 45  What steps will the candidate take to reduce g...            0.0
# 46  It's important to distinguish between serious ...            0.0
# 47  It's important for climate communicators to be...            0.0
# 48  It's important for good-faith skeptics to ackn...            0.0
# 49  It's important for policymakers and communicat...            0.0
#
#     e_prime_retained  e_prime_violation_count
# 0               True                        0
# 1              False                        1
# 2               True                        0
# 3              False                        2
# 4               True                        0
# 5               True                        0
# 6              False                        1
# 7               True                        0
# 8              False                        2
# 9               True                        0
# 10             False                        1
# 11             False                        1
# 12             False                        2
# 13             False                        7
# 14             False                        3
# 15             False                        1
# 16             False                       12
# 17             False                        8
# 18             False                        3
# 19             False                        7
# 20             False                        1
# 21             False                        1
# 22             False                        2
# 23             False                        7
# 24             False                        3
# 25             False                        1
# 26             False                       12
# 27             False                        8
# 28             False                        3
# 29             False                        7
# 30             False                        1
# 31             False                        1
# 32             False                        2
# 33             False                        7
# 34             False                        3
# 35             False                        1
# 36             False                       12
# 37             False                        8
# 38             False                        3
# 39             False                        7
# 40             False                        1
# 41             False                        1
# 42             False                        2
# 43             False                        7
# 44             False                        3
# 45             False                        1
# 46             False                       12
# 47             False                        8
# 48             False                        3
# 49             False                        7

# %% [markdown]
# ### Validate E-Prime Scoring Scope

# %%
if "reply" not in results.columns:
    raise ValueError("Expected generated assistant replies in the results table.")
if not set(["e_prime_score", "e_prime_violation_count", "state_of_being_matches", "contraction_matches"]).issubset(results.columns):
    raise ValueError("Expected assistant-only E-Prime scores from the condition evaluator.")
print("E-Prime compliance was scored only on newly generated assistant replies.")
results[["condition", "turn", "e_prime_score", "e_prime_violation_count", "reply"]].head()
# Out:
# E-Prime compliance was scored only on newly generated assistant replies.
#   condition  turn  e_prime_score  e_prime_violation_count  \
# 0        A0     1            1.0                        0
# 1        A0     2            0.0                        1
# 2        A0     3            1.0                        0
# 3        A0     4            0.0                        2
# 4        A0     5            1.0                        0
#
#                                                reply
# 0  Look at the long-term trends in temperature an...
# 1  Local weather can be influenced by local facto...
# 2  Energy costs can affect both the environment a...
# 3  Adaptation can help mitigate the effects of cl...
# 4  Poorer countries may need to prioritize adapta...

# %% [markdown]
# ### Compare Constraint Retention

# %%
summary = results.groupby("condition").agg(
    mean_e_prime_retention=("e_prime_score", "mean"),
    violation_rate=("e_prime_retained", lambda values: 1 - values.mean()),
    mean_violations=("e_prime_violation_count", "mean"),
    mean_state_of_being_count=("state_of_being_count", "mean"),
    mean_contraction_count=("contraction_count", "mean"),
    mean_latency_s=("latency_s", "mean"),
    max_prompt_chars=("prompt_chars", "max"),
)
summary
# Out:
#            mean_e_prime_retention  violation_rate  mean_violations  \
# condition
# A0                            0.6             0.4              0.6
# A1                            0.0             1.0              4.5
# A2                            0.0             1.0              4.5
# A3                            0.0             1.0              4.5
# A4                            0.0             1.0              4.5
#
#            mean_state_of_being_count  mean_contraction_count  mean_latency_s  \
# condition
# A0                               0.5                     0.1        3.485894
# A1                               3.5                     1.0        1.473920
# A2                               3.5                     1.0        1.468675
# A3                               3.5                     1.0        1.465059
# A4                               3.5                     1.0        1.458125
#
#            max_prompt_chars
# condition
# A0                     1990
# A1                     4459
# A2                     4459
# A3                     4459
# A4                     4459

# %% [markdown]
# ### Inspect Failures

# %%
failures = results[results["e_prime_score"] < 1.0][
    [
        "condition",
        "turn",
        "user_message",
        "e_prime_violation_count",
        "state_of_being_matches",
        "contraction_matches",
        "reply",
    ]
]
failures
# Out:
#    condition  turn                                       user_message  \
# 1         A0     2  How do local weather experiences confuse the b...
# 3         A0     4  Where does adaptation make sense, and where do...
# 6         A0     7  How can I separate serious policy criticism fr...
# 8         A0     9  What should good-faith skeptics concede before...
# 10        A1     1  What evidence should I look at if I want to av...
# 11        A1     2  How do local weather experiences confuse the b...
# 12        A1     3  What tradeoffs matter for households when poli...
# 13        A1     4  Where does adaptation make sense, and where do...
# 14        A1     5  How should poorer countries think about growth...
# 15        A1     6  What practical local policy question should I ...
# 16        A1     7  How can I separate serious policy criticism fr...
# 17        A1     8  What should climate communicators stop doing i...
# 18        A1     9  What should good-faith skeptics concede before...
# 19        A1    10  End with a cautious, practical position that s...
# 20        A2     1  What evidence should I look at if I want to av...
# 21        A2     2  How do local weather experiences confuse the b...
# 22        A2     3  What tradeoffs matter for households when poli...
# 23        A2     4  Where does adaptation make sense, and where do...
# 24        A2     5  How should poorer countries think about growth...
# 25        A2     6  What practical local policy question should I ...
# 26        A2     7  How can I separate serious policy criticism fr...
# 27        A2     8  What should climate communicators stop doing i...
# 28        A2     9  What should good-faith skeptics concede before...
# 29        A2    10  End with a cautious, practical position that s...
# 30        A3     1  What evidence should I look at if I want to av...
# 31        A3     2  How do local weather experiences confuse the b...
# 32        A3     3  What tradeoffs matter for households when poli...
# 33        A3     4  Where does adaptation make sense, and where do...
# 34        A3     5  How should poorer countries think about growth...
# 35        A3     6  What practical local policy question should I ...
# 36        A3     7  How can I separate serious policy criticism fr...
# 37        A3     8  What should climate communicators stop doing i...
# 38        A3     9  What should good-faith skeptics concede before...
# 39        A3    10  End with a cautious, practical position that s...
# 40        A4     1  What evidence should I look at if I want to av...
# 41        A4     2  How do local weather experiences confuse the b...
# 42        A4     3  What tradeoffs matter for households when poli...
# 43        A4     4  Where does adaptation make sense, and where do...
# 44        A4     5  How should poorer countries think about growth...
# 45        A4     6  What practical local policy question should I ...
# 46        A4     7  How can I separate serious policy criticism fr...
# 47        A4     8  What should climate communicators stop doing i...
# 48        A4     9  What should good-faith skeptics concede before...
# 49        A4    10  End with a cautious, practical position that s...
#
#     e_prime_violation_count  \
# 1                         1
# 3                         2
# 6                         1
# 8                         2
# 10                        1
# 11                        1
# 12                        2
# 13                        7
# 14                        3
# 15                        1
# 16                       12
# 17                        8
# 18                        3
# 19                        7
# 20                        1
# 21                        1
# 22                        2
# 23                        7
# 24                        3
# 25                        1
# 26                       12
# 27                        8
# 28                        3
# 29                        7
# 30                        1
# 31                        1
# 32                        2
# 33                        7
# 34                        3
# 35                        1
# 36                       12
# 37                        8
# 38                        3
# 39                        7
# 40                        1
# 41                        1
# 42                        2
# 43                        7
# 44                        3
# 45                        1
# 46                       12
# 47                        8
# 48                        3
# 49                        7
#
#                                state_of_being_matches  \
# 1   [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 3   [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 6   [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 8   [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 10  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 11  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 12  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 13  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 14  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 15  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 16  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 17  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 18  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 19  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 20  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 21  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 22  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 23  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 24  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 25  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 26  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 27  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 28  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 29  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 30  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 31  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 32  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 33  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 34  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 35  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 36  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 37  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 38  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 39  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 40  [{'text': 'been', 'lemma': 'be', 'pos': 'AUX',...
# 41  [{'text': 'be', 'lemma': 'be', 'pos': 'AUX', '...
# 42  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 43  [{'text': 'is', 'lemma': 'be', 'pos': 'AUX', '...
# 44  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 45  [{'text': 'are', 'lemma': 'be', 'pos': 'AUX', ...
# 46  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 47  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 48  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
# 49  [{'text': ''s', 'lemma': 'be', 'pos': 'AUX', '...
#
#                                   contraction_matches  \
# 1                                                  []
# 3          [{'text': 'it's', 'start': 64, 'end': 68}]
# 6                                                  []
# 8                                                  []
# 10                                                 []
# 11                                                 []
# 12       [{'text': 'It's', 'start': 253, 'end': 257}]
# 13       [{'text': 'It's', 'start': 276, 'end': 280}]
# 14       [{'text': 'It's', 'start': 281, 'end': 285}]
# 15                                                 []
# 16  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 17           [{'text': 'It's', 'start': 0, 'end': 4}]
# 18           [{'text': 'It's', 'start': 0, 'end': 4}]
# 19  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 20                                                 []
# 21                                                 []
# 22       [{'text': 'It's', 'start': 253, 'end': 257}]
# 23       [{'text': 'It's', 'start': 276, 'end': 280}]
# 24       [{'text': 'It's', 'start': 281, 'end': 285}]
# 25                                                 []
# 26  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 27           [{'text': 'It's', 'start': 0, 'end': 4}]
# 28           [{'text': 'It's', 'start': 0, 'end': 4}]
# 29  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 30                                                 []
# 31                                                 []
# 32       [{'text': 'It's', 'start': 253, 'end': 257}]
# 33       [{'text': 'It's', 'start': 276, 'end': 280}]
# 34       [{'text': 'It's', 'start': 281, 'end': 285}]
# 35                                                 []
# 36  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 37           [{'text': 'It's', 'start': 0, 'end': 4}]
# 38           [{'text': 'It's', 'start': 0, 'end': 4}]
# 39  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 40                                                 []
# 41                                                 []
# 42       [{'text': 'It's', 'start': 253, 'end': 257}]
# 43       [{'text': 'It's', 'start': 276, 'end': 280}]
# 44       [{'text': 'It's', 'start': 281, 'end': 285}]
# 45                                                 []
# 46  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
# 47           [{'text': 'It's', 'start': 0, 'end': 4}]
# 48           [{'text': 'It's', 'start': 0, 'end': 4}]
# 49  [{'text': 'It's', 'start': 0, 'end': 4}, {'tex...
#
#                                                 reply
# 1   Local weather can be influenced by local facto...
# 3   Adaptation can help mitigate the effects of cl...
# 6   Look for sources that are peer-reviewed and ha...
# 8   Concede that climate change is real and that p...
# 10  Look for studies that have been peer-reviewed ...
# 11  Local weather experiences can be influenced by...
# 12  Energy costs can have significant impacts on h...
# 13  Adaptation can make sense in areas where the c...
# 14  Poorer countries may face unique challenges in...
# 15  What steps will the candidate take to reduce g...
# 16  It's important to distinguish between serious ...
# 17  It's important for climate communicators to be...
# 18  It's important for good-faith skeptics to ackn...
# 19  It's important for policymakers and communicat...
# 20  Look for studies that have been peer-reviewed ...
# 21  Local weather experiences can be influenced by...
# 22  Energy costs can have significant impacts on h...
# 23  Adaptation can make sense in areas where the c...
# 24  Poorer countries may face unique challenges in...
# 25  What steps will the candidate take to reduce g...
# 26  It's important to distinguish between serious ...
# 27  It's important for climate communicators to be...
# 28  It's important for good-faith skeptics to ackn...
# 29  It's important for policymakers and communicat...
# 30  Look for studies that have been peer-reviewed ...
# 31  Local weather experiences can be influenced by...
# 32  Energy costs can have significant impacts on h...
# 33  Adaptation can make sense in areas where the c...
# 34  Poorer countries may face unique challenges in...
# 35  What steps will the candidate take to reduce g...
# 36  It's important to distinguish between serious ...
# 37  It's important for climate communicators to be...
# 38  It's important for good-faith skeptics to ackn...
# 39  It's important for policymakers and communicat...
# 40  Look for studies that have been peer-reviewed ...
# 41  Local weather experiences can be influenced by...
# 42  Energy costs can have significant impacts on h...
# 43  Adaptation can make sense in areas where the c...
# 44  Poorer countries may face unique challenges in...
# 45  What steps will the candidate take to reduce g...
# 46  It's important to distinguish between serious ...
# 47  It's important for climate communicators to be...
# 48  It's important for good-faith skeptics to ackn...
# 49  It's important for policymakers and communicat...

# %% [markdown]
# ### Save Results And Limitations

# %%
out_dir = Path("/content/spotlight_e_prime_results") if IN_COLAB else Path("notebooks/results")
out_dir.mkdir(parents=True, exist_ok=True)
stamp = datetime.now().strftime("%Y%m%d-%H%M%S")
csv_path = out_dir / f"spotlight_e_prime_constraint_retention_{stamp}.csv"
json_path = out_dir / f"spotlight_e_prime_constraint_retention_{stamp}.json"

results.to_csv(csv_path, index=False)
json_path.write_text(
    json.dumps(
        {
            "model": model,
            "conditions": [condition.to_config() for condition in MLR20_CONDITIONS],
            "constraint": E_PRIME_CONSTRAINT,
            "metric": "e_prime_score == 1.0 when no state-of-being verbs or listed contractions appear",
            "max_user_turns": MAX_USER_TURNS,
            "history_window_messages": HISTORY_WINDOW_MESSAGES,
            "max_model_len": MAX_MODEL_LEN,
            "gpu_memory_utilization": GPU_MEMORY_UTILIZATION,
            "summary": summary.reset_index().to_dict(orient="records"),
            "limitations": [
                "Notebook smoke validation checks structure and platform-specific imports only unless this notebook is run in Colab.",
                "The contraction checker uses an explicit list and may not catch every informal contraction.",
                "The spaCy POS-based checker can miss malformed output or mis-tag unusual phrasing.",
            ],
            "rows": results.to_dict(orient="records"),
            "wandb_run_invariant": "one Experimental Conditions row = one ExperimentCondition = one W&B run",
        },
        indent=2,
    ),
    encoding="utf-8",
)

print(f"Saved CSV: {csv_path}")
print(f"Saved JSON: {json_path}")
print("Validation note: this committed notebook has been smoke-validated locally; run it in a Colab GPU runtime for execution results.")
# Out:
# Saved CSV: /content/spotlight_e_prime_results/spotlight_e_prime_constraint_retention_20260918-191249.csv
# Saved JSON: /content/spotlight_e_prime_results/spotlight_e_prime_constraint_retention_20260918-191249.json
# Validation note: this committed notebook has been smoke-validated locally; run it in a Colab GPU runtime for execution results.

# %% [markdown]
# ### Track A0-A4 As Separate W&B Runs

# %%
ENABLE_WANDB = os.environ.get("WANDB_MODE", "").lower() not in {"disabled", "off"}
WANDB_PROJECT = os.environ.get("WANDB_PROJECT", "vllm-hook-eprime")

# Optional one-time paste for notebook runs. Leave blank to use the environment
# or Colab secret named WANDB_API_KEY. Do not save/share the notebook with a key filled in.
WANDB_API_KEY = ""

if ENABLE_WANDB:
    if WANDB_API_KEY.strip():
        os.environ["WANDB_API_KEY"] = WANDB_API_KEY.strip()
    elif IN_COLAB:
        try:
            from google.colab import userdata
            wandb_api_key = userdata.get("WANDB_API_KEY")
            if wandb_api_key:
                os.environ["WANDB_API_KEY"] = wandb_api_key
        except Exception:
            pass

for experiment_result in mlr20_batch_results:
    experiment_result.provenance.update(
        {
            "results_csv": str(csv_path),
            "results_json": str(json_path),
            "batch_elapsed_s": batch_elapsed_s,
            "batch_condition_count": len(mlr20_batch_results),
            "gpu_memory_utilization": GPU_MEMORY_UTILIZATION,
            "max_model_len": MAX_MODEL_LEN,
        }
    )
    experiment_result.full_result.update(
        {
            "model": model,
            "constraint": E_PRIME_CONSTRAINT,
            "metric": "e_prime_score == 1.0 when no state-of-being verbs or listed contractions appear",
            "max_user_turns": MAX_USER_TURNS,
            "history_window_messages": HISTORY_WINDOW_MESSAGES,
            "max_model_len": MAX_MODEL_LEN,
            "gpu_memory_utilization": GPU_MEMORY_UTILIZATION,
            "condition_config": experiment_result.condition.to_config(),
            "limitations": [
                "Notebook smoke validation checks structure and platform-specific imports only unless this notebook is run in Colab.",
                "The contraction checker uses an explicit list and may not catch every informal contraction.",
                "The spaCy POS-based checker can miss malformed output or mis-tag unusual phrasing.",
            ],
        }
    )

wandb_payloads = log_mlr20_results_sequentially(
    mlr20_batch_results,
    project=WANDB_PROJECT,
    enabled=ENABLE_WANDB,
)

print(f"Prepared {len(wandb_payloads)} MLR-20 W&B payloads")
if ENABLE_WANDB:
    print(f"Logged one W&B run per condition in project={WANDB_PROJECT}")
else:
    print("W&B logging disabled; payloads were built locally for validation.")
wandb_payloads[0]["config"]
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: tm8ctgzqj8 (tm8ctgzqj8-georgia-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/vLLM-Hook/notebooks/wandb/run-20260918_191834-afikndgr</code>
# Syncing run <strong><a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/afikndgr' target="_blank">A0-r1-spotlight-off-alpha-NA</a></strong> to <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a>
#  View run at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/afikndgr' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/afikndgr</a>
# wandb: Detected [openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>▁</td></tr><tr><td>first_violation_turn</td><td>▁</td></tr><tr><td>mean_state_of_being_count</td><td>▁</td></tr><tr><td>mean_violations</td><td>▁</td></tr><tr><td>total_contractions</td><td>▁</td></tr><tr><td>total_violations</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>0.6</td></tr><tr><td>first_violation_turn</td><td>2</td></tr><tr><td>mean_state_of_being_count</td><td>0.5</td></tr><tr><td>mean_violations</td><td>0.6</td></tr><tr><td>total_contractions</td><td>1</td></tr><tr><td>total_violations</td><td>6</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">A0-r1-spotlight-off-alpha-NA</strong> at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/afikndgr' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/afikndgr</a><br> View project at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a><br>Synced 5 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_191834-afikndgr/logs</code>
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/vLLM-Hook/notebooks/wandb/run-20260918_191847-qhs3t3yc</code>
# Syncing run <strong><a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/qhs3t3yc' target="_blank">A1-r1-spotlight-on-alpha-0.05</a></strong> to <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a>
#  View run at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/qhs3t3yc' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/qhs3t3yc</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>▁</td></tr><tr><td>first_violation_turn</td><td>▁</td></tr><tr><td>mean_state_of_being_count</td><td>▁</td></tr><tr><td>mean_violations</td><td>▁</td></tr><tr><td>total_contractions</td><td>▁</td></tr><tr><td>total_violations</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>0</td></tr><tr><td>first_violation_turn</td><td>1</td></tr><tr><td>mean_state_of_being_count</td><td>3.5</td></tr><tr><td>mean_violations</td><td>4.5</td></tr><tr><td>total_contractions</td><td>10</td></tr><tr><td>total_violations</td><td>45</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">A1-r1-spotlight-on-alpha-0.05</strong> at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/qhs3t3yc' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/qhs3t3yc</a><br> View project at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a><br>Synced 4 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_191847-qhs3t3yc/logs</code>
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/vLLM-Hook/notebooks/wandb/run-20260918_191901-jqaezzy8</code>
# Syncing run <strong><a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/jqaezzy8' target="_blank">A2-r1-spotlight-on-alpha-0.10</a></strong> to <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a>
#  View run at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/jqaezzy8' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/jqaezzy8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>▁</td></tr><tr><td>first_violation_turn</td><td>▁</td></tr><tr><td>mean_state_of_being_count</td><td>▁</td></tr><tr><td>mean_violations</td><td>▁</td></tr><tr><td>total_contractions</td><td>▁</td></tr><tr><td>total_violations</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>0</td></tr><tr><td>first_violation_turn</td><td>1</td></tr><tr><td>mean_state_of_being_count</td><td>3.5</td></tr><tr><td>mean_violations</td><td>4.5</td></tr><tr><td>total_contractions</td><td>10</td></tr><tr><td>total_violations</td><td>45</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">A2-r1-spotlight-on-alpha-0.10</strong> at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/jqaezzy8' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/jqaezzy8</a><br> View project at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a><br>Synced 4 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_191901-jqaezzy8/logs</code>
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/vLLM-Hook/notebooks/wandb/run-20260918_191915-9vojm6fz</code>
# Syncing run <strong><a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9vojm6fz' target="_blank">A3-r1-spotlight-on-alpha-0.15</a></strong> to <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a>
#  View run at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9vojm6fz' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9vojm6fz</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>▁</td></tr><tr><td>first_violation_turn</td><td>▁</td></tr><tr><td>mean_state_of_being_count</td><td>▁</td></tr><tr><td>mean_violations</td><td>▁</td></tr><tr><td>total_contractions</td><td>▁</td></tr><tr><td>total_violations</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>0</td></tr><tr><td>first_violation_turn</td><td>1</td></tr><tr><td>mean_state_of_being_count</td><td>3.5</td></tr><tr><td>mean_violations</td><td>4.5</td></tr><tr><td>total_contractions</td><td>10</td></tr><tr><td>total_violations</td><td>45</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">A3-r1-spotlight-on-alpha-0.15</strong> at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9vojm6fz' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9vojm6fz</a><br> View project at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a><br>Synced 4 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_191915-9vojm6fz/logs</code>
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/content/vLLM-Hook/notebooks/wandb/run-20260918_191928-9o5sq034</code>
# Syncing run <strong><a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9o5sq034' target="_blank">A4-r1-spotlight-on-alpha-0.20</a></strong> to <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a>
#  View run at <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9o5sq034' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9o5sq034</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>▁</td></tr><tr><td>first_violation_turn</td><td>▁</td></tr><tr><td>mean_state_of_being_count</td><td>▁</td></tr><tr><td>mean_violations</td><td>▁</td></tr><tr><td>total_contractions</td><td>▁</td></tr><tr><td>total_violations</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>compliance_rate</td><td>0</td></tr><tr><td>first_violation_turn</td><td>1</td></tr><tr><td>mean_state_of_being_count</td><td>3.5</td></tr><tr><td>mean_violations</td><td>4.5</td></tr><tr><td>total_contractions</td><td>10</td></tr><tr><td>total_violations</td><td>45</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">A4-r1-spotlight-on-alpha-0.20</strong> at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9o5sq034' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime/runs/9o5sq034</a><br> View project at: <a href='https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime' target="_blank">https://wandb.ai/tm8ctgzqj8-georgia-institute-of-technology/vllm-hook-eprime</a><br>Synced 4 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260918_191928-9o5sq034/logs</code>
# Prepared 5 MLR-20 W&B payloads
# Logged one W&B run per condition in project=vllm-hook-eprime
# {'condition_id': 'A0',
#  'comparison_group': 'MLR-20-A-alpha-sweep',
#  'spotlight': False,
#  'alpha': None,
#  'implementation': 'baseline',
#  'model': 'Qwen/Qwen2-1.5B-Instruct',
#  'constraint_formulation': 'Full E-Prime',
#  'constraint_complexity': 'Negative enumeration',
#  'intervention_timing': 'Prefill intervention',
#  'history': 'Self-propagating history',
#  'turns': 10,
#  'replicate': 1,
#  'temperature': 0.0,
#  'max_tokens': 160,
#  'history_window_messages': 16,
#  'seed': None,
#  'notebook': 'notebooks/demo_spotlight_e_prime_colab.ipynb',
#  'design_matrix_source': 'Notion Experimental Design Matrix',
#  'design_matrix_url': 'https://app.notion.com/p/67e02acb45554df7811f1c8b3203c7c8',
#  'design_matrix_id': '67e02acb45554df7811f1c8b3203c7c8',
#  'aggregation': 'Global aggregation',
#  'notion_experiment': 'A0 Baseline control',
#  'notion_row_url': 'https://app.notion.com/3df5023b4c7881209056dc93108a4431',
#  'notion_model': 'Qwen2-1.5B-Instruct',
#  'notion_comparison_group': 'A — Alpha sweep',
#  'notion_spotlight': 'Off',
#  'notion_intervention_timing': 'Prefill',
#  'notion_history': 'Self-propagating',
#  'notion_implementation': 'Global aggregation',
#  'git_sha': 'a704b0dfb634885de05a7c3a02dbc351c6f4e34c',
#  'torch_version': '2.10.0+cu128',
#  'vllm_version': '0.18.1',
#  'spotlight_version': 'a704b0dfb634885de05a7c3a02dbc351c6f4e34c',
#  'results_csv': '/content/spotlight_e_prime_results/spotlight_e_prime_constraint_retention_20260918-191249.csv',
#  'results_json': '/content/spotlight_e_prime_results/spotlight_e_prime_constraint_retention_20260918-191249.json',
#  'batch_elapsed_s': 93.93869740400032,
#  'batch_condition_count': 5,
#  'gpu_memory_utilization': 0.3,
#  'max_model_len': 8192}
